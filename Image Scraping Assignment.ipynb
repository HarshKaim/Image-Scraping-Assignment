# %% [markdown]
# Go to this given URL and solve the following questions
#
# URL: https://www.youtube.com/@PW-Foundation/videos
#
# Youtube is not allowing webscraping as you can see below I am getting empty list in result

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen

# %%
website_url='https://www.youtube.com/@PW-Foundation/videos'

# %%
response=requests.get(website_url)

# %%
response.text
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="6lXORklnfRIJ2wZb3RCf8Q">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false,"644029907":true,"1822726157":true}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="6lXORklnfRIJ2wZb3RCf8Q">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# ...

# %%
response.content
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="7y63PUGP35B_M-PLgXcJCA">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false,"641353869":true,"644029907":true,"1822726157":true}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="7y63PUGP35B_M-PLgXcJCA">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.
# ...

# %%
beautiful_response=bs(response.text,'html.parser')

# %%
beautiful_response
# Out:
# <!DOCTYPE html>
# ...

# %%
beautiful_response.find_all('div')
# Out:
# [<div class="ytd-searchbox-spt" id="search-container" slot="search-container"></div>,
#  <div class="ytd-searchbox-spt" id="search-input" slot="search-input"><input autocapitalize="none" autocomplete="off" autocorrect="off" hidden="" id="search" name="search_query" spellcheck="false" tabindex="0" type="text"/></div>,
# ...

# %%
beautiful_response2=bs(response.content,'html.parser')

# %%
beautiful_response2.find_all('div',{'class':'style-scope ytd-rich-grid-renderer'})
# Out:
# []

# %%
url_opened=urlopen(website_url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
type(beautiful_response)
# Out:
# bs4.BeautifulSoup

# %%
type(url_opened)
# Out:
# http.client.HTTPResponse

# %%
url_opened_beauty=bs(url_opened,'html.parser')

# %%
type(url_opened_beauty)
# Out:
# bs4.BeautifulSoup

# %%
url_opened_beauty.find_all('div',{'class':'autoplay skeleton-light-border-bottom'})
# Out:
# []
